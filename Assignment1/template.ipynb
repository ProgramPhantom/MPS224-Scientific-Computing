# %% [markdown]
# **Registration Number:** (your reg number here)

# %% [markdown]
# # Part 1: Translation functions

# %%
def boop_to_kebab(B):
    """
    Add your docstring here and fill in the body of the function.
    """

# %% [markdown]
# # Part 2: Cracking the code

# %%
# Your code here

# %% [markdown]
# # Part 3: The spork

# %%
# Your code here

# %% [markdown]
# # Part 4: Going further

# %% [markdown]
# Your code and markdown cells here.

# %% [markdown]
# # Acknowledgements

# %% [markdown]
# Record in this cell:
# * Sources used (books, papers, Wikipedia, YouTube).
# * Help received.
#
#
# Fill out the section below to acknowledge AI assistance.

# %% [markdown]
# ## Acknowledgement of AI Assistance

# %% [markdown]
# ### 1. Declaration
# Please mark the relevant box with an 'x':
# - [ ] I did **not** use any AI assistance for this assignment.
# - [ ] I **did** use AI assistance, as detailed below.
#
# ### 2. AI Services Used
# *(Delete this text and list the specific tools used, e.g., ChatGPT 4o, GitHub Copilot, Google Gemini)*
#
# ### 3. Description of Usage
# *(Delete this text and replace it with a brief description of how you used these tools. Be specific about which parts of the code or report were influenced.)*
#
# * **Code Generation:** (e.g., Used to generate the syntax for the matplotlib figure layout...)
# * **Debugging:** (e.g., Used to interpret the ValueError in cell 4...)
# * **Concepts:** (e.g., Used to explain how the FFT algorithm handles discrete data...)
#
# ### 4. Statement of Understanding
# By submitting this assignment, I confirm that:
# 1.  I have tested and verified that all code behaves as expected.
# 2.  I fully understand the logic and syntax of the code submitted.
# 3.  I am capable of explaining the function of every line if asked.
# 4.  The written text of this report is my own work.

# %% [markdown]
# # Sandbox

# %%
# For other code used when writing your notebook.
# This part will not be marked.
# This part can be blank in the final submission.
